# %%
from automata.fa.nfa import NFA
from automata.fa.dfa import DFA
from helpers import get_automaton_display

# %%
nfa = NFA.from_regex('(1(10)*0|0(01)*1)*', input_symbols={'0','1'})

# %%
get_automaton_display(DFA.from_nfa(nfa))
